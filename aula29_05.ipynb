# %% [markdown]
# <a href="https://colab.research.google.com/github/Tomatopopo/ppi-galerinha/blob/main/aula29_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## lista de exrcícios - lógica de programação
#
# Resolva cada problema pensando na lógica

# %% [markdown]
# ###1
#
#   Leia um número inteiro e exiba o seu sucessor e antecessor

# %%
numero = int(input("selecione um número"))
antecessor = numero - 1
print(f"antecessor: {antecessor}")
sucessor = numero + 1
print(f"sucessor: {sucessor}")
# Out:
# selecione um número9
# antecessor: 8
# sucessor: 10

# %% [markdown]
# ###2
#
# Leia dois números e apresente a soma, subtração, multiplicação e divisão entre eles. (com funções)

# %%
def soma(n1 : float,n2:float):
  return n1 + n2

def subtração(n1:float,n2:float):
  return n1 - n2

def multiplicação(n1:float,n2:float):
  return n1*n2

def divisão(n1:float,n2:float):
  if n2 ==0:
    return "operação invalida"
  return n1/n2

n1 = float(input("insira o primeiro numnero: "))
n2 = float(input("insira o segundo numnero: "))

print(f"soma: {soma(n1,n2)}")
print(f"subtração: {subtração(n1,n2)}")
print(f"multiplicação: {multiplicação(n1,n2)}")
print(f"divisão: {divisão(n1,n2)}")
# Out:
# insira o primeiro numnero: 6
# insira o segundo numnero: 9
# soma: 15.0
# subtração: -3.0
# multiplicação: 54.0
# divisão: 0.6666666666666666

# %% [markdown]
# ###3
#
# Leia a idade de uma pessoa em anos e converta para meses e dias

# %%
idade = int(input("digite a idade: "))
meses = idade * 12
print(f"{meses} meses")
dias = idade * 365
print(f"{dias} dias")
# Out:
# digite a idade: 16
# 192, meses
# 5840 dias

# %% [markdown]
# inverter um numero

# %%
numero = int(input("digite um numero: "))
auxiliar = numero
numerof = 0
inverso= 0
while auxiliar != 0:
  resto = auxiliar % 10
  inverso = inverso *10 + resto
  auxiliar //= 10

print(f"inverso do numero {numero} = {inverso}")
# Out:
# digite um numero: 5678657
# inverso do numero 5678657 = 7568765

# %% [markdown]
# ####numero perfeito. numero narcisista

# %%
def n_perfeito(numero:int):
  divisor = 2
  perfeito = 1
  while (divisor <= numero//2):
    if (numero % divisor == 0):
      perfeito += divisor
    divisor +=1
  return numero == perfeito
numero = int(input('digite um numero: '))
n_perfeito(numero)
# Out:
# digite um numero: 22
# False

# %%
def digitos(numero:int):
  auxiliar = numero
  digitos = 1
  while auxiliar != 0:
    auxiliar //= 10
    if auxiliar != 0:
      digitos += 1
  return digitos
numero =  int(input("numero: "))
digitos(numero)
# Out:
# numero: 128719376
# 9

# %%
def narcisista(numero: int):
  auxiliar = numero
  digito = 0
  narcisista = 0
  q_digitos = digitos(numero)
  while auxiliar != 0:
    digito = auxiliar % 10
    auxiliar //= 10
    narcisista+= digito**q_digitos
  return narcisista == numero
numero =  int(input("numero: "))
narcisista(numero)
# Out:
# numero: 432
# False
